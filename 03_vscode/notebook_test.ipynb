# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'product': ['A', 'B', 'C', 'D'],
    'price': [10, 20, 30, 40],
    'quantity': [100, 200, 300, 400]
})
df
# Out:
#   product  price  quantity
# 0       A     10       100
# 1       B     20       200
# 2       C     30       300
# 3       D     40       400

# %%
df['total'] = df['price'] * df['quantity']
df['total']
# Out:
# 0     1000
# 1     4000
# 2     9000
# 3    16000
# Name: total, dtype: int64
